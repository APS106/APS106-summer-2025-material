# %%
#MCQ

# %%
x = 1
y = 10

if y > 10: 
    x = 2*y +1

print('x should be 21, and x =', x)

# %%
x = 1
y = 10

for i in range(y//2 +1):
    x += i

print('x should be 21, and x =', x)

# %%
x = 1
y = 10

x = min(y, 10*x) + max(y, x) + min(y, x) 

print('x should be 21, and x =', x)

# %%
x = 1
y = 10

x == x + 2*y

print('x should be 21, and x =', x)

# %%
accumulator = ""

for i in range(10,16,5):
    if i % 5 == 0:
        accumulator += str(i % 10)
print(accumulator)

# %%
def membership_eligibility(age, weekly_workouts):
    if age >= 50:
        if weekly_workouts >= 3:
            return "Eligible"
        else:
            return "Not Eligible"
    elif age >= 20 and age < 50:
        if weekly_workouts >= 5:
            return "Eligible"
        else:
            return "Not Eligible"
    elif age < 20:
        if weekly_workouts >= 6:
            return "Eligible"
        else:
            return "Not Eligible"

print(membership_eligibility(55, 2))
print(membership_eligibility(45, 5))
print(membership_eligibility(18, 5))
print(membership_eligibility(65, 2))

# %%
word = "DeenoTheCat"
loc = word.lower().rfind('the')
print(word[loc-1:1:-1][::-1])

# %%
for i in range(6): 
    if i % 3 == 0: 
        file = open('my_file.txt', 'w') 
        file.write('2') 
    else: 
        file = open('my_file.txt', 'a') 
        file.write('1') 

file.close() 

file = open('my_file.txt', 'r') 

print(file.read())

# %%
#Question 2

print('Begin')

def func_a(n):
    print("A")
    return n

def func_b(x):
    result = x * 3
    print("B", result)
    return result

def func_c(x, y):
    return x ** y
    print(x ** y)

def func_d(input_string):
    for i in range(len(input_string)):
        print("Outer loop index", i)
        for j in range(len(input_string)):
            print("Inner loop index", j)
    return "Hello!"

def func_e(param):
    return 'E-' + str(param)

i = func_c(2, 1)

j = func_a(func_b(2))

print('C', func_c(i, j))

print(func_e(i))

# %%
#Question 3a

'''



'''


def validate_email(address):
    """
    (str) -> bool

    Returns True if the address is in valid email address format.
    Returns False otherwise.
    
    A valid email address must contain an '@' symbol and a period ('.') after the '@'.
    The period must not come immediately after the '@' and must not be the last character.
    """
    
    if not ('@' in address):
        return False

    at_index = address.find('@')
    period_index = address[at_index:].find('.')

    # Check if period is found, not immediately after '@', and not the last character
    if period_index == -1 or period_index == at_index + 1 or period_index == len(address) - 1:
        return False

    return True

# %%
#Question 3b

'''


'''

def clean_email_subject(subject):
    """
    (str) -> str

    Returns a string that is a copy of the original subject string but with all leading and trailing spaces removed, and all consecutive spaces removed.
    """

    # Remove leading and trailing spaces
    subject = subject.strip()
    
    result = ""
    previous_char = ""
    
    for char in subject:
        # Add character to result if it's not a space or if the previous character was not a space
        if char != ' ' or previous_char != ' ':
            result += char
        previous_char = char
    
    return result


def clean_email_subject2(subject):
    """
    (str) -> str

    Returns a string that is a copy of the original subject string but with all leading and trailing spaces removed, and all consecutive spaces removed.
    """

    # Remove leading and trailing spaces
    subject = subject.strip()
    
    result = ""
    previous_char = ""
    
    for i in range(len(subject)):
        # Add character to result if it's not a space or if the previous character was not a space
        if not((subject[i] == ' ') and (subject[i+1] == ' ')):
            result += subject[i]
    
    return result

clean_email_subject2('   we like     Apples      ')

# %%
#Question 4a

'''


'''
  
def print_keywords(keyword_file):
    '''
    (str) -> int

    Brief description
    '''
    with open(keyword_file, 'r') as keywords:
        count = 0
        for line in keywords:
            print(line.strip())
            count += 1
    return count


def print_keywords2(keyword_file):
    '''
    (str) -> int

    Brief description
    '''
    keywords = open(keyword_file, 'r'):
    count = 0
    for line in keywords:
        print(line.strip())
        count += 1
    keywords.close()
    return count

# %%
#Question 4b

'''

'''

def find_substrings1(string, substring):
    count = 0
    index = 0
    new_string = string
    while True:
        index = new_string.find(substring)
        if index != -1:
            new_string = new_string[index + len(substring):]
            count += 1
            print(count, len(string) - len(new_string) - len(substring))
        else:
            break
    return count
 
def find_substrings3(string, substring):
    count = 0
    index = 0
    total = len(string)
    while string.count(substring) != 0:
        par = string.partition(substring)
        string = par[2]
        count += 1
        index += len(par[0] + par[1])
        print(count, index-len(substring))
    return count

# %%
#Question 5a

'''

'''

def factorial(n):
    """
    (int) -> int
    Computes the factorial of n (n!)
    
    Example: 
    factorial(3) is equivalent to 3! = 3*2*1 = 6
    factorial(0) = 1
    """

    if n == 0 or n == 1:
    return 1
    
    result = 1
    for i in range(2, n + 1):
        result *= i
    
    return result

# %%
#Question 5b

'''

    
    

'''

def cos_series(x, n):
    '''
    (float, int) -> float
    
    Calculates cos(x) using the cosine series with n terms.
    Returns cos(x) estimate rounded to 3 decimal places.
    Assumes valid inputs.
    '''

    cos_x = 0.0
    for i in range(n):
        term = ((-1) ** i) * (x ** (2 * i)) / factorial(2 * i)
        cos_x += term
    
    return round(cos_x, 3)
